# %% [markdown]
# # Mnist dataset keras neural network using regularization method to avoid overfitting

# %%
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import InputLayer, Flatten, Dense

# %%
# read the data
(X_train_full, y_train_full), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
X_train, y_train = X_train_full[:-10000]/255., y_train_full[:-10000]
X_valid, y_valid = X_train_full[-10000:]/255., y_train_full[-10000:]
X_test = X_test/255.

# %%
# fix the random numbers generator
tf.random.set_seed(42)

# create a sequantial model of an input, three hidden and an output layer
model = Sequential()
model.add(InputLayer(input_shape=[28, 28]))
model.add(Flatten())
model.add(Dense(200, activation="relu"))
model.add(Dense(200, activation="relu"))
model.add(Dense(200, activation="relu"))
model.add(Dense(200, activation="softmax"))

# %%
model.compile(optimizer="Adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                                  patience=5,
                                                  restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size = 32,
                    validation_data=(X_valid, y_valid),
                    callbacks=[early_stopping])

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"\nThe accuracy on the test set is: {100*test_accuracy:.1f}%")
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 12s 7ms/step - loss: 0.2723 - accuracy: 0.9189 - val_loss: 0.1377 - val_accuracy: 0.9597
# Epoch 2/100
# 1563/1563 [==============================] - 12s 7ms/step - loss: 0.1056 - accuracy: 0.9681 - val_loss: 0.1116 - val_accuracy: 0.9653
# Epoch 3/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0712 - accuracy: 0.9777 - val_loss: 0.0914 - val_accuracy: 0.9738
# Epoch 4/100
# 1563/1563 [==============================] - 12s 7ms/step - loss: 0.0576 - accuracy: 0.9823 - val_loss: 0.0915 - val_accuracy: 0.9745
# Epoch 5/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0472 - accuracy: 0.9853 - val_loss: 0.1040 - val_accuracy: 0.9731
# Epoch 6/100
# 1563/1563 [==============================] - 12s 7ms/step - loss: 0.0364 - accuracy: 0.9887 - val_loss: 0.1266 - val_accuracy: 0.9702
# Epoch 7/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0320 - accuracy: 0.9899 - val_loss: 0.1253 - val_accuracy: 0.9727
# Epoch 8/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0274 - accuracy: 0.9914 - val_loss: 0.1117 - val_accuracy: 0.9729
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0803 - accuracy: 0.9768
#
# The accuracy on the test set is: 97.7%

# %%
x_values = range(1, len(history.history['loss'])+1)
fig, ax = plt.subplots(figsize = (8,6))
ax.plot(x_values, history.history['loss'], "r-", label = "Train loss")
ax.plot(x_values, history.history['val_loss'], "b-", label = "Validation loss")
ax.set_ylabel("Loss (lines)")
ax.set_xlabel("Epoch")
ax.legend(loc='upper center')
ax.grid()

ax1 = ax.twinx()

ax1.plot(x_values, history.history['accuracy'], "ro", label = "Train")
ax1.plot(x_values, history.history['val_accuracy'], "bo", label = "Validation")
ax1.set_ylabel("Accuracy (dots)")

plt.xticks(x_values)
plt.legend()
plt.show()

# %%
##############################################################################

# %%
# create a sequantial model of an input, three hidden and an output layer
model = Sequential()
model.add(InputLayer(input_shape=[28, 28]))
model.add(Flatten())
model.add(Dense(200, activation="relu"))
model.add(Dense(200, activation="relu"))
model.add(Dense(200, activation="relu"))
model.add(Dense(10, activation="softmax"))

# %%
model.compile(optimizer="Adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                                  patience=5,
                                                  restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size = 32,
                    validation_data=(X_valid, y_valid),
                    callbacks=[early_stopping])

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"\nThe accuracy on the test set is: {100*test_accuracy:.1f}%")
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 11s 6ms/step - loss: 0.2260 - accuracy: 0.9303 - val_loss: 0.1209 - val_accuracy: 0.9637
# Epoch 2/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.0976 - accuracy: 0.9698 - val_loss: 0.1072 - val_accuracy: 0.9664
# Epoch 3/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0700 - accuracy: 0.9778 - val_loss: 0.0829 - val_accuracy: 0.9743
# Epoch 4/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0531 - accuracy: 0.9836 - val_loss: 0.0831 - val_accuracy: 0.9757
# Epoch 5/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.0463 - accuracy: 0.9852 - val_loss: 0.1021 - val_accuracy: 0.9723
# Epoch 6/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0379 - accuracy: 0.9877 - val_loss: 0.1204 - val_accuracy: 0.9719
# Epoch 7/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.0308 - accuracy: 0.9900 - val_loss: 0.1180 - val_accuracy: 0.9715
# Epoch 8/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.0280 - accuracy: 0.9913 - val_loss: 0.1029 - val_accuracy: 0.9752
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0778 - accuracy: 0.9768
#
# The accuracy on the test set is: 97.7%

# %%
x_values = range(1, len(history.history['loss'])+1)
fig, ax = plt.subplots(figsize = (8,6))
ax.plot(x_values, history.history['loss'], "r-", label = "Train loss")
ax.plot(x_values, history.history['val_loss'], "b-", label = "Validation loss")
ax.set_ylabel("Loss (lines)")
ax.set_xlabel("Epoch")
ax.legend(loc='upper center')
ax.grid()

ax1 = ax.twinx()

ax1.plot(x_values, history.history['accuracy'], "ro", label = "Train")
ax1.plot(x_values, history.history['val_accuracy'], "bo", label = "Validation")
ax1.set_ylabel("Accuracy (dots)")

plt.xticks(x_values)
plt.legend()
plt.show()

# %%
########################################################################################

# %%
#regularization method such as Dropout to address the issue of overfitting during the training process.
from tensorflow.keras.layers import Dropout

# %%
tf.random.set_seed(42)

# create a sequantial model of an input, three hidden and an output layer
model1 = Sequential()
model1.add(InputLayer(input_shape=[28, 28]))
model1.add(Flatten())
model1.add(Dense(200, activation="relu"))
model1.add(Dropout(rate=0.25))
model1.add(Dense(200, activation="relu"))
model1.add(Dropout(rate=0.25))
model1.add(Dense(200, activation="relu"))
model1.add(Dropout(rate=0.25))
model1.add(Dense(10, activation="softmax"))

# %%
# compile the model
model1.compile(optimizer="Adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                                  patience=5,
                                                  restore_best_weights=True)

history = model1.fit(X_train, y_train, epochs=100, batch_size = 32,
                    validation_data=(X_valid, y_valid),
                    callbacks=[early_stopping])


test_loss, test_accuracy = model1.evaluate(X_test, y_test)
print(f"\nThe accuracy on the test set is: {100*test_accuracy:.1f}%")
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 12s 7ms/step - loss: 0.3343 - accuracy: 0.8966 - val_loss: 0.1218 - val_accuracy: 0.9636
# Epoch 2/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1666 - accuracy: 0.9505 - val_loss: 0.1176 - val_accuracy: 0.9671
# Epoch 3/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1314 - accuracy: 0.9610 - val_loss: 0.0978 - val_accuracy: 0.9707
# Epoch 4/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1129 - accuracy: 0.9669 - val_loss: 0.0922 - val_accuracy: 0.9740
# Epoch 5/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1002 - accuracy: 0.9701 - val_loss: 0.0896 - val_accuracy: 0.9740
# Epoch 6/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0907 - accuracy: 0.9720 - val_loss: 0.0978 - val_accuracy: 0.9735
# Epoch 7/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0836 - accuracy: 0.9739 - val_loss: 0.0907 - val_accuracy: 0.9760
# Epoch 8/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0777 - accuracy: 0.9765 - val_loss: 0.0866 - val_accuracy: 0.9764
# Epoch 9/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0725 - accuracy: 0.9787 - val_loss: 0.0854 - val_accuracy: 0.9764
# Epoch 10/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0687 - accuracy: 0.9782 - val_loss: 0.0830 - val_accuracy: 0.9774
# Epoch 11/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.0653 - accuracy: 0.9800 - val_loss: 0.0883 - val_accuracy: 0.9774
# Epoch 12/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0612 - accuracy: 0.9816 - val_loss: 0.0898 - val_accuracy: 0.9777
# Epoch 13/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0552 - accuracy: 0.9821 - val_loss: 0.0919 - val_accuracy: 0.9787
# Epoch 14/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0575 - accuracy: 0.9826 - val_loss: 0.0800 - val_accuracy: 0.9793
# Epoch 15/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0532 - accuracy: 0.9837 - val_loss: 0.0928 - val_accuracy: 0.9786
# Epoch 16/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0509 - accuracy: 0.9843 - val_loss: 0.0755 - val_accuracy: 0.9804
# Epoch 17/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.0507 - accuracy: 0.9843 - val_loss: 0.0860 - val_accuracy: 0.9791
# Epoch 18/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0483 - accuracy: 0.9855 - val_loss: 0.0824 - val_accuracy: 0.9812
# Epoch 19/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0450 - accuracy: 0.9863 - val_loss: 0.0864 - val_accuracy: 0.9802
# Epoch 20/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0460 - accuracy: 0.9863 - val_loss: 0.0766 - val_accuracy: 0.9814
# Epoch 21/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0428 - accuracy: 0.9875 - val_loss: 0.0949 - val_accuracy: 0.9800
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0837 - accuracy: 0.9807
#
# The accuracy on the test set is: 98.1%

# %%
x_values = range(1, len(history.history['loss'])+1)
fig, ax = plt.subplots(figsize = (8,6))
ax.plot(x_values, history.history['loss'], "r-", label = "Train loss")
ax.plot(x_values, history.history['val_loss'], "b-", label = "Validation loss")
ax.set_ylabel("Loss (lines)")
ax.set_xlabel("Epoch")
ax.legend(loc='upper center')
ax.grid()

ax1 = ax.twinx()

ax1.plot(x_values, history.history['accuracy'], "ro", label = "Train")
ax1.plot(x_values, history.history['val_accuracy'], "bo", label = "Validation")
ax1.set_ylabel("Accuracy (dots)")

plt.xticks(x_values)
plt.legend()
plt.show()
